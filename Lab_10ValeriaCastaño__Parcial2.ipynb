# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/CURSO5/blob/main/Lab_10ValeriaCasta%C3%B1o__Parcial2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Laboratorio 10. Examen Parcial - Parte 2**
# # **Escribe el Nombre del Curso**: Estadística y probabilidad.
# ## **Escribe tu nombre completo**: Valeria Castaño Espitia
#
# > Email: valecastano162006@gmail.com
#
# > Código estudiantil: T00081173
#
#
# ---

# %% [markdown]
# ### **Ensayo.**
#
#
# El Laboratorio 10 constituyó una oportunidad práctica para integrar los conocimientos teóricos de estadística y probabilidad en el análisis de datos reales. A través del uso del lenguaje de programación Python y sus librerías especializadas, fue posible aplicar conceptos como estadística descriptiva, muestreo, análisis de normalidad, técnicas de bootstrap y regresión lineal. Esta experiencia permitió comprender que el manejo de datos no se limita a procesar cifras, sino a interpretarlas con sentido crítico y científico, especialmente dentro del campo de la ingeniería biomédica, donde las decisiones deben basarse en evidencia cuantitativa y verificable.
#
#
# El proceso comenzó con la **importación y depuración de una base de datos** que contenía información de 74 estudiantes y 26 variables. En esta etapa se identificaron valores nulos y se reemplazaron con el dato más frecuente, garantizando la coherencia interna del conjunto. Además, se estandarizaron categorías como el transporte y el grupo sanguíneo, corrigiendo inconsistencias que podían alterar el análisis posterior. Este primer paso permitió evidenciar que la calidad de los datos es un requisito indispensable para cualquier estudio estadístico.
#
# Una vez organizada la información, se calcularon las **medidas descriptivas** —promedio, desviación estándar, valores máximos y mínimos—, las cuales ofrecieron una visión general del comportamiento de las variables. Se observó que la asistencia promedio superó el 85 % y que las calificaciones tendieron a ubicarse entre 2,8 y 3,5. Estos resultados reflejaron un desempeño académico regular con poca dispersión, lo que indica una población relativamente homogénea.
#
# La siguiente fase consistió en la **representación gráfica de las variables** mediante histogramas y diagramas de caja. Estas visualizaciones permitieron observar la distribución de datos y detectar posibles valores atípicos, especialmente en el peso y la estatura. En general, las gráficas mostraron concentraciones de datos cercanas al promedio, lo que sugiere cierta simetría en el comportamiento de la mayoría de las variables. Este tipo de análisis visual facilitó la comprensión de patrones que no siempre son evidentes en los resultados numéricos.
#
# Posteriormente, se verificó la **normalidad de las distribuciones** comparando los histogramas reales con curvas de densidad teórica. Las variables peso y estatura mostraron una tendencia clara hacia la forma de campana típica de la distribución normal, mientras que las calificaciones y la asistencia presentaron ligeras asimetrías. Este análisis permitió comprender que no todos los fenómenos siguen modelos teóricos perfectos, pero que conocer su grado de aproximación es esencial para seleccionar los métodos estadísticos adecuados.
#
# Durante el desarrollo del laboratorio también se aplicó la **técnica de muestreo aleatorio y bootstrap**, extrayendo múltiples muestras simuladas con el fin de estudiar la variabilidad de las medias. Los resultados mostraron que, al aumentar el número de muestras, la media muestral se estabiliza en torno al valor poblacional, lo cual confirma el **Teorema del Límite Central**. Este comportamiento demuestra la validez del muestreo estadístico como herramienta para realizar inferencias confiables sin necesidad de analizar toda la población.
#
# Finalmente, se llevó a cabo un **modelo de regresión lineal simple** con la estatura como variable independiente y el peso como variable dependiente. El análisis arrojó un coeficiente de determinación de **R² = 0.43**, lo que significa que cerca del 43 % de la variación en el peso puede explicarse a partir de la estatura. Este resultado evidenció una relación positiva y coherente con la lógica biológica, y demostró cómo los modelos estadísticos permiten predecir comportamientos a partir de datos observados.
#
#
#
# El Laboratorio 10 permitió integrar la teoría estadística con la práctica computacional de manera concreta. A lo largo del proceso, se comprendió que el análisis de datos requiere tanto precisión técnica como capacidad interpretativa. Las fases de limpieza, descripción, muestreo y modelamiento lineal mostraron que los números adquieren valor cuando se traducen en conclusiones significativas. En el contexto de la ingeniería biomédica, esta competencia es fundamental, ya que los datos son la base para validar hipótesis, diseñar dispositivos y evaluar resultados clínicos. En conclusión, este laboratorio no solo fortaleció habilidades analíticas, sino que reafirmó la importancia de la estadística como un puente entre la información y la innovación científica.

# %% [markdown]
# # **Temario**

# %% [markdown]
# <a name="inicio"></a>
#
#
# ## **1.** [Librerias para Trabar en R y Python](#T1)
# ## **2.** [Base de Datos - Estudiando la base de datos - DataMinig](#T2)
#
# ## **3.** [Estadísticas Descriptivas (Variables Numéricas)](#T3)
#
# ## **4.** [Variables Cuantitativas - Gráficas BoxPlot e Histograma](#T4)
#
# ## **5.** [Verificando la Normalidad](#T5)
#
# ## **6.** [Tomando una muestra aleatoria de tamaño 50](#T6)
#
# ## **7.** [Tomando mil muestras -  Bootstraps para una variable](#T7)
#
#
# ## **8.** [Tomando mil muestras -  Bootstraps para Varias variables](#T8)
#
# ## **9.** [Regresión Lineal Simple](#T9)
#
# ## **10.** [Matriz de correlación](#T10)
#
# ## **11.** [Regresión lineal - MINIMOS CUADRADOS - Least Squares](#T11)

# %% [markdown]
# [ULTIMO](#ULTIMO)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T1"></a>
# ## **1. Librerias para Trabar en R y Python**

# %% [markdown]
# ```python
#
# # @title **A. Librerias para Trabar en Python**
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
# from scipy import stats
# import warnings
# warnings.filterwarnings("ignore", category=FutureWarning)
# from sympy.functions.combinatorial.factorials import factorial
# import math
# from math import sqrt
# from numpy.ma.core import log
# from sympy import integrate, init_printing
# from sympy.abc import x
# print("Setup Complete")

# %%
# @title **A. Librerias para Trabar en Python**
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sympy.functions.combinatorial.factorials import factorial
import math
from math import sqrt
from numpy.ma.core import log
from sympy import integrate, init_printing
from sympy.abc import x
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T2"></a>
# ## **2. Base de Datos - Estudiando la base de datos - DataMinig**

# %%
# @title **A. Nuestra Base de datos en Pyhton**
url = 'https://raw.githubusercontent.com/JSEFERINO/Teoria-de-Probabilidad-MEYCD/main/DATOS202460ULTIMOS.csv'
df = pd.read_csv(url,delimiter=';')
df
# Out:
#            CURSO  ASISTENCIA2  ASISTENCIA1  PARCIAL 1  PARCIAL 2   NRC  \
# 0   PROBABILIDAD          100           90        3.6       4.30  2314
# 1   ESTADISTICAI           70           75        0.9       2.50  1136
# 2   PROBABILIDAD           85           95        3.9       3.80  2314
# 3   PROBABILIDAD            5            5        2.9       0.50  2314
# 4   ESTADISTICAI           20           70        3.7       0.55  1009
# ..           ...          ...          ...        ...        ...   ...
# 69  PROBABILIDAD           90           90        2.3       2.10  2314
# 70  PROBABILIDAD           85           95        2.0       3.10  2314
# 71  ESTADISTICAI           65           75        1.7       2.95  1136
# 72  ESTADISTICAI          100          100        2.3       3.20  2313
# 73  ESTADISTICAI          100          100        3.8       3.10  1136
#
#       PROGRAMA  EDAD  PESO  ESTATURA  ...  \
# 0   F_NEGOCIOS    20    55       160  ...
# 1      DERECHO    18    80       185  ...
# 2   F_NEGOCIOS    19    60       158  ...
# 3     MECANICA    18    72       181  ...
# 4   PSICOLOGÍA    19    45       163  ...
# ..         ...   ...   ...       ...  ...
# 69  F_NEGOCIOS    18    59       176  ...
# 70  F_NEGOCIOS    18    60       171  ...
# 71     DERECHO    20    55       164  ...
# 72  PSICOLOGÍA    19    67       171  ...
# 73     DERECHO    18    60       165  ...
#
#     A: Facilidad para aprender cosas nuevas B: Memoria y atención  \
# 0                                      BAJO                  ALTO
# 1                                      ALTO                  ALTO
# 2                                      BAJO                  BAJO
# 3                                     MEDIO                  ALTO
# 4                                      ALTO                 MEDIO
# ..                                      ...                   ...
# 69                                    MEDIO                 MEDIO
# 70                                     BAJO                  BAJO
# 71                                     BAJO                 MEDIO
# 72                                     BAJO                  BAJO
# 73                                     ALTO                  ALTO
#
#    C: Relacionar tu experiencias con lo que aprendes D: Autoestima  \
# 0                                              MEDIO          ALTO
# 1                                               ALTO          ALTO
# 2                                               BAJO          BAJO
# 3                                               BAJO         MEDIO
# 4                                              MEDIO          ALTO
# ..                                               ...           ...
# 69                                             MEDIO          ALTO
# 70                                              ALTO          ALTO
# 71                                             MEDIO          ALTO
# 72                                              BAJO          BAJO
# 73                                              BAJO          ALTO
#
#    E: Actitud hacia el Aprendizaje F: Ambiente Familiar para estudiar  \
# 0                             ALTO                               BAJO
# 1                             ALTO                               ALTO
# 2                            MEDIO                              MEDIO
# 3                            MEDIO                               ALTO
# 4                             ALTO                               BAJO
# ..                             ...                                ...
# 69                            ALTO                               ALTO
# 70                            ALTO                               BAJO
# 71                            ALTO                               ALTO
# 72                           MEDIO                               BAJO
# 73                            ALTO                               ALTO
#
#    G: Ansiedad académica H: Recursos Educativos  \
# 0                   BAJO                   BAJO
# 1                  MEDIO                  MEDIO
# 2                  MEDIO                  MEDIO
# 3                  MEDIO                   ALTO
# 4                  MEDIO                   BAJO
# ..                   ...                    ...
# 69                  ALTO                   BAJO
# 70                  ALTO                   BAJO
# 71                  BAJO                   BAJO
# 72                  BAJO                   BAJO
# 73                  BAJO                   BAJO
#
#    I: Mentalidad para superar adversidades K: Regularidad en el estudio
# 0                                     ALTO                         ALTO
# 1                                    MEDIO                        MEDIO
# 2                                    MEDIO                        MEDIO
# 3                                    MEDIO                        MEDIO
# 4                                     ALTO                         BAJO
# ..                                     ...                          ...
# 69                                    ALTO                         ALTO
# 70                                    ALTO                         BAJO
# 71                                   MEDIO                         BAJO
# 72                                    BAJO                         BAJO
# 73                                    ALTO                        MEDIO
#
# [74 rows x 26 columns]

# %%
# @title **B. Cantidad de estudiantes y variables en Python**
No_estudiantes_y_Variables = df.shape
print('(No estudiantes, No Variables) = ',No_estudiantes_y_Variables)
# Out:
# (No estudiantes, No Variables) =  (74, 26)

# %%
# @title **C. Mostrar información del tipo de las  variables y registros nulos (null) en Python**
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 26 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   CURSO                                              74 non-null     object
#  1   ASISTENCIA2                                        74 non-null     int64
#  2   ASISTENCIA1                                        74 non-null     int64
#  3   PARCIAL 1                                          74 non-null     float64
#  4   PARCIAL 2                                          74 non-null     float64
#  5   NRC                                                74 non-null     int64
#  6   PROGRAMA                                           74 non-null     object
#  7   EDAD                                               74 non-null     int64
#  8   PESO                                               74 non-null     int64
#  9   ESTATURA                                           74 non-null     int64
#  10  SEXO                                               74 non-null     object
#  11  ESTADO_CIVIL                                       74 non-null     object
#  12  ESTRATO                                            73 non-null     object
#  13  URBANO                                             74 non-null     object
#  14  TRANSPORTE                                         74 non-null     object
#  15  GR_SANGUINEO                                       74 non-null     object
#  16   A: Facilidad para aprender cosas nuevas           74 non-null     object
#  17  B: Memoria y atención                              74 non-null     object
#  18  C: Relacionar tu experiencias con lo que aprendes  74 non-null     object
#  19  D: Autoestima                                      74 non-null     object
#  20  E: Actitud hacia el Aprendizaje                    74 non-null     object
#  21  F: Ambiente Familiar para estudiar                 74 non-null     object
#  22  G: Ansiedad académica                              74 non-null     object
#  23  H: Recursos Educativos                             74 non-null     object
#  24  I: Mentalidad para superar adversidades            74 non-null     object
#  25  K: Regularidad en el estudio                       74 non-null     object
# dtypes: float64(2), int64(6), object(18)
# memory usage: 15.2+ KB

# %%
# @title **D. Mostrar los diferentes tipos de cursos en Python**
Tipos_cursos = df['CURSO'].unique()
print('Cursos=', Tipos_cursos)
# Out:
# Cursos= ['PROBABILIDAD' 'ESTADISTICAI']

# %%
# @title **E. Mostrar los diferentes tipos de programas en Python**
Tipos_programas = df['PROGRAMA'].unique()
print('Programas=', Tipos_programas)
# Out:
# Programas= ['F_NEGOCIOS' 'DERECHO' 'MECANICA' 'PSICOLOGÍA' 'C_DATOS' 'SISTEMAS'
#  'BIOMEDICA' 'INDUSTRIAL' 'ECONOMIA' 'MECATRONICA' 'NAVAL' 'C_SOCIAL'
#  'QUIMICA' 'ELECTRICA' 'CIVIL' 'CONTADURIA']

# %%
# @title **F. Mostrar los diferentes tipos de estratos en Python**
Tipos_estratos = df['ESTRATO'].unique()
print('Estratos=', Tipos_estratos)
# Out:
# Estratos= ['II' 'III' 'V' 'I' 'IV' nan]

# %%
# @title **G. Mostrar la posicion de los estudiantes con "nan" en estrato en Python**
nan_estrato_positions = df[df['ESTRATO'].isnull()].index.tolist()
print("Posiciones de estudiantes con 'nan' en estrato:", nan_estrato_positions)
# Out:
# Posiciones de estudiantes con 'nan' en estrato: [17]

# %%
# @title **H. Mostrar la posicion de los estudiantes con "nan" en estrato**
df['ESTRATO'].head(20)
# Out:
# 0      II
# 1     III
# 2     III
# 3       V
# 4      II
# 5       I
# 6      IV
# 7     III
# 8     III
# 9       I
# 10      I
# 11     II
# 12     II
# 13      I
# 14     IV
# 15     IV
# 16    III
# 17    NaN
# 18      I
# 19      V
# Name: ESTRATO, dtype: object

# %%
# @title **I. Reemplazamos el dato perdido con el valosr mas frecuente de la variable**
df['ESTRATO'].fillna('II', inplace=True)
print(df['ESTRATO'].unique())
# Out:
# ['II' 'III' 'V' 'I' 'IV']

# %%
# @title **J. Mostrar los diferentes tipos de transporte**
Tipos_transporte = df['TRANSPORTE'].unique()
print('Transporte = ', Tipos_transporte)
# Out:
# Transporte =  ['Transcaribe' 'El bus que me deja mas cerca' 'Particular' 'Mototaxi'
#  'Taxi']

# %%
# @title **K. Cambia en TRANSPORTE "El bus que me deja mas cerca" por "Bus"**

df['TRANSPORTE'] = df['TRANSPORTE'].replace('El bus que me deja mas cerca', 'Bus')
print('Transporte = ', df['TRANSPORTE'].unique())
# Out:
# Transporte =  ['Transcaribe' 'Bus' 'Particular' 'Mototaxi' 'Taxi']

# %%
# @title **L. Mostrar los diferentes tipos de grupos sanguíneos**
Tipos_sangre = df['GR_SANGUINEO'].unique()
print('Grupo Sanguíneo=', Tipos_sangre)
# Out:
# Grupo Sanguíneo= ['O positivo (O+)' 'A positivo (A +)' 'B positivo (B +)' 'O negativo (O-)']

# %%
# @title **M. Cambia en TRANSPORTE "El bus que me deja mas cerca" por "Bus"**

df['GR_SANGUINEO'] = df['GR_SANGUINEO'].replace('O positivo (O+)', 'O_POS')
df['GR_SANGUINEO'] = df['GR_SANGUINEO'].replace('A positivo (A +)', 'A_POS')
df['GR_SANGUINEO'] = df['GR_SANGUINEO'].replace('B positivo (B +)', 'B_POS')
df['GR_SANGUINEO'] = df['GR_SANGUINEO'].replace('AB positivo (AB +)', 'AB_POS')
df['GR_SANGUINEO'] = df['GR_SANGUINEO'].replace('O negativo (O -)', 'O_NEG')
df['GR_SANGUINEO'] = df['GR_SANGUINEO'].replace('A negativo (A -)', 'A_NEG')
df['GR_SANGUINEO'] = df['GR_SANGUINEO'].replace('B negativo (B -)', 'B_NEG')
df['GR_SANGUINEO'] = df['GR_SANGUINEO'].replace('AB negativo (AB -)', 'AB_NEG')
print('Grupo Sanguíneo=', df['GR_SANGUINEO'].unique())
# Out:
# Grupo Sanguíneo= ['O_POS' 'A_POS' 'B_POS' 'O negativo (O-)']

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T3"></a>
# ## **3. Estadísticas Descriptivas (Variables Numéricas)**

# %%
# @title **A. Estadísticas descriptivas generales**
stats_descriptivas = df.describe()
# Mostrar estadísticas descriptivas
stats_descriptivas
# Out:
#        ASISTENCIA2  ASISTENCIA1  PARCIAL 1  PARCIAL 2          NRC       EDAD  \
# count    74.000000    74.000000  74.000000  74.000000    74.000000  74.000000
# mean     88.243243    86.756757   2.844595   3.114865  1549.851351  18.702703
# std      17.564605    15.112193   0.994112   0.871022   619.364161   1.190484
# min       5.000000     5.000000   0.900000   0.500000  1009.000000  17.000000
# 25%      85.000000    80.000000   2.000000   2.900000  1010.000000  18.000000
# 50%      90.000000    90.000000   2.850000   3.150000  1136.000000  18.000000
# 75%     100.000000    95.000000   3.600000   3.687500  2314.000000  19.000000
# max     100.000000   100.000000   4.900000   4.650000  2314.000000  22.000000
#
#              PESO    ESTATURA
# count   74.000000   74.000000
# mean    63.324324  168.391892
# std     11.354931    8.533283
# min     42.000000  153.000000
# 25%     55.000000  163.000000
# 50%     62.000000  168.000000
# 75%     70.000000  174.000000
# max    102.000000  192.000000

# %%
# @title **B. Estadísticas descriptivas para variables categóricas**
categ_stats = df[['CURSO', 'PROGRAMA', 'URBANO', 'TRANSPORTE', 'SEXO', 'ESTRATO', 'GR_SANGUINEO']].describe()

# Mostrar estadísticas descriptivas
categ_stats
# Out:
#                CURSO    PROGRAMA     URBANO   TRANSPORTE      SEXO ESTRATO  \
# count             74          74         74           74        74      74
# unique             2          16         28            5         2       5
# top     PROBABILIDAD  F_NEGOCIOS  Cartagena  Transcaribe  Femenino      II
# freq              48          16         17           35        42      26
#
#        GR_SANGUINEO
# count            74
# unique            4
# top           O_POS
# freq             44

# %%
# @title **D. Redefiniendo una variable - Una nueva Variable**
df['DEFINITIVA'] = df['PARCIAL 1']
df
# Out:
#            CURSO  ASISTENCIA2  ASISTENCIA1  PARCIAL 1  PARCIAL 2   NRC  \
# 0   PROBABILIDAD          100           90        3.6       4.30  2314
# 1   ESTADISTICAI           70           75        0.9       2.50  1136
# 2   PROBABILIDAD           85           95        3.9       3.80  2314
# 3   PROBABILIDAD            5            5        2.9       0.50  2314
# 4   ESTADISTICAI           20           70        3.7       0.55  1009
# ..           ...          ...          ...        ...        ...   ...
# 69  PROBABILIDAD           90           90        2.3       2.10  2314
# 70  PROBABILIDAD           85           95        2.0       3.10  2314
# 71  ESTADISTICAI           65           75        1.7       2.95  1136
# 72  ESTADISTICAI          100          100        2.3       3.20  2313
# 73  ESTADISTICAI          100          100        3.8       3.10  1136
#
#       PROGRAMA  EDAD  PESO  ESTATURA  ... B: Memoria y atención  \
# 0   F_NEGOCIOS    20    55       160  ...                  ALTO
# 1      DERECHO    18    80       185  ...                  ALTO
# 2   F_NEGOCIOS    19    60       158  ...                  BAJO
# 3     MECANICA    18    72       181  ...                  ALTO
# 4   PSICOLOGÍA    19    45       163  ...                 MEDIO
# ..         ...   ...   ...       ...  ...                   ...
# 69  F_NEGOCIOS    18    59       176  ...                 MEDIO
# 70  F_NEGOCIOS    18    60       171  ...                  BAJO
# 71     DERECHO    20    55       164  ...                 MEDIO
# 72  PSICOLOGÍA    19    67       171  ...                  BAJO
# 73     DERECHO    18    60       165  ...                  ALTO
#
#    C: Relacionar tu experiencias con lo que aprendes D: Autoestima  \
# 0                                              MEDIO          ALTO
# 1                                               ALTO          ALTO
# 2                                               BAJO          BAJO
# 3                                               BAJO         MEDIO
# 4                                              MEDIO          ALTO
# ..                                               ...           ...
# 69                                             MEDIO          ALTO
# 70                                              ALTO          ALTO
# 71                                             MEDIO          ALTO
# 72                                              BAJO          BAJO
# 73                                              BAJO          ALTO
#
#    E: Actitud hacia el Aprendizaje F: Ambiente Familiar para estudiar  \
# 0                             ALTO                               BAJO
# 1                             ALTO                               ALTO
# 2                            MEDIO                              MEDIO
# 3                            MEDIO                               ALTO
# 4                             ALTO                               BAJO
# ..                             ...                                ...
# 69                            ALTO                               ALTO
# 70                            ALTO                               BAJO
# 71                            ALTO                               ALTO
# 72                           MEDIO                               BAJO
# 73                            ALTO                               ALTO
#
#    G: Ansiedad académica H: Recursos Educativos  \
# 0                   BAJO                   BAJO
# 1                  MEDIO                  MEDIO
# 2                  MEDIO                  MEDIO
# 3                  MEDIO                   ALTO
# 4                  MEDIO                   BAJO
# ..                   ...                    ...
# 69                  ALTO                   BAJO
# 70                  ALTO                   BAJO
# 71                  BAJO                   BAJO
# 72                  BAJO                   BAJO
# 73                  BAJO                   BAJO
#
#    I: Mentalidad para superar adversidades K: Regularidad en el estudio  \
# 0                                     ALTO                         ALTO
# 1                                    MEDIO                        MEDIO
# 2                                    MEDIO                        MEDIO
# 3                                    MEDIO                        MEDIO
# 4                                     ALTO                         BAJO
# ..                                     ...                          ...
# 69                                    ALTO                         ALTO
# 70                                    ALTO                         BAJO
# 71                                   MEDIO                         BAJO
# 72                                    BAJO                         BAJO
# 73                                    ALTO                        MEDIO
#
#    DEFINITIVA
# 0         3.6
# 1         0.9
# 2         3.9
# 3         2.9
# 4         3.7
# ..        ...
# 69        2.3
# 70        2.0
# 71        1.7
# 72        2.3
# 73        3.8
#
# [74 rows x 27 columns]

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T4"></a>
# ## **4. Variables Cuantitativas - Gráficas BoxPlot e Histograma**

# %%
# @title **A. Gráficas BoxPlot e Histograma: DEFINITIVA, EDAD, ESTATURA**
plt.figure(figsize=(8, 4))

# Histograma definitivas
plt.subplot(2, 3, 1)
plt.hist(df['DEFINITIVA'], bins=10, color='pink')
# plt.title('Distribución de las Definitivas')
# plt.xlabel('Definitiva (0->5)')
plt.ylabel('Frecuencia - Valeria Castaño')

# Histograma de edades
plt.subplot(2, 3, 2)
plt.hist(df['EDAD'], bins=10, color='yellow')
# plt.title('Distribución de Edad')
# plt.xlabel('Edad (Años)')
plt.ylabel('Frecuencia - Valeria Castaño')

# Boxplot de las definitivas
plt.subplot(2, 3, 4)
sns.boxplot(data=df, x='DEFINITIVA', color='lightblue')
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('Definitiva (0->5)')

# Boxplot Edad
plt.subplot(2, 3, 5)
sns.boxplot(data=df, x='EDAD', color='teal')
plt.xlabel('Edad (Años - Valeria Castaño)')
# plt.title('Distribución de Notas Definitivas')

# Histograma de la estatura
plt.subplot(2, 3, 3)
plt.hist(df['ESTATURA'], bins=10, color='violet')
# plt.title('Distribución de Asistencia')
plt.ylabel('Frecuencia - Valeria Castaño')
# plt.xlabel('Estatura (cm)')

# Boxplot de estatura
plt.subplot(2, 3, 6)
sns.boxplot(data=df, x='ESTATURA', color='salmon')
# plt.title('Distribución de la Asistencia')
plt.xlabel('Estatura (cm) - Valeria Castaño')

# ajustar espaciado entre subplot
plt.tight_layout()
plt.show()

# %%
# @title **B. Gráficas BoxPlot e Histograma:PARCIAL 2, PESO, ASISTENCIA1**
plt.figure(figsize=(8, 4))

# Histograma PARCIAL 2
plt.subplot(2, 3, 1)
plt.hist(df['PARCIAL 2'], bins=10, color='lightgreen')
# plt.title('Distribución de las Definitivas')
# plt.xlabel('Definitiva (0->5)')
plt.ylabel('Frecuencia')

# Histograma de edades
plt.subplot(2, 3, 2)
plt.hist(df['PESO'], bins=10, color='gold')
# plt.title('Distribución de Edad')
# plt.xlabel('Edad (Años)')
plt.ylabel('Frecuencia')

# Boxplot de las PARCIAL 2
plt.subplot(2, 3, 4)
sns.boxplot(data=df, x='PARCIAL 2', color='skyblue')
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('PARCIAL 2 (0->5)')

# Boxplot PESO
plt.subplot(2, 3, 5)
sns.boxplot(data=df, x='PESO', color='chocolate')
plt.xlabel('PESO (Kgs)')
# plt.title('Distribución de Notas Definitivas')

# Histograma de la ASISTENCIA1
plt.subplot(2, 3, 3)
plt.hist(df['ASISTENCIA1'], bins=10, color='orange')
# plt.title('Distribución de Asistencia')
plt.ylabel('Frecuencia - ')
# plt.xlabel('Estatura (cm)')

# Boxplot de ASISTENCIA1
plt.subplot(2, 3, 6)
sns.boxplot(data=df, x='ASISTENCIA1', color='lime')
# plt.title('Distribución de la Asistencia')
plt.xlabel('ASISTENCIA1 (cm) - Valeria Castaño')

# ajustar espaciado entre subplot
plt.tight_layout()
plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T5"></a>
# ## **5. Verificando la Normalidad**

# %%
# @title **A. Recordando nuestra variables**
df.columns
# Out:
# Index(['CURSO', 'ASISTENCIA2', 'ASISTENCIA1', 'PARCIAL 1', 'PARCIAL 2', 'NRC',
#        'PROGRAMA', 'EDAD', 'PESO', 'ESTATURA', 'SEXO', 'ESTADO_CIVIL',
#        'ESTRATO', 'URBANO', 'TRANSPORTE', 'GR_SANGUINEO',
#        ' A: Facilidad para aprender cosas nuevas', 'B: Memoria y atención',
#        'C: Relacionar tu experiencias con lo que aprendes', 'D: Autoestima',
#        'E: Actitud hacia el Aprendizaje', 'F: Ambiente Familiar para estudiar',
#        'G: Ansiedad académica', 'H: Recursos Educativos',
#        'I: Mentalidad para superar adversidades',
#        'K: Regularidad en el estudio', 'DEFINITIVA'],
#       dtype='object')

# %%
# @title **B. Histograma vs Densidad Normal - PESO**

sns.histplot(df['PESO'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)

plt.show()

# %%
# @title **C. Histograma vs Densidad Normal - Todas las variables**
plt.figure(figsize=(8, 4))

# Boxplot de las ASISTENCIA2
plt.subplot(2, 3, 1)
sns.histplot(df['ASISTENCIA2'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4), color='pink')
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('ASISTENCIA2 - Valeria Castaño')


# Boxplot de las PARCIAL 1
plt.subplot(2, 3, 2)
sns.histplot(df['PARCIAL 1'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4), color='orange')
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('PARCIAL 1- Valeria Castaño')


# Boxplot de las PESO
plt.subplot(2, 3, 4)
sns.histplot(df['PESO'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4), color='lightblue')
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('PESO - Valeria Castaño')

# Boxplot PESO
plt.subplot(2, 3, 5)
sns.histplot(df["EDAD"], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4), color='teal')
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('EDAD - Valeria Castaño')


# Histograma de la ASISTENCIA1
plt.subplot(2, 3, 3)

sns.histplot(df['ESTATURA'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4), color='violet')
# plt.title('Distribución de Notas Definitivas')
plt.ylabel('Frecuencia - Valeria Castaño')
# plt.xlabel('Estatura (cm)')

# Boxplot de ASISTENCIA1
plt.subplot(2, 3, 6)
sns.histplot(df['DEFINITIVA'], kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4), color='salmon')
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('DEFINITIVA - Valeria Castaño')

# ajustar espaciado entre subplot
plt.tight_layout()
plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T6"></a>
# ## **6. Tomando una muestra aleatoria**

# %%
# @title **A. Tomando una muestra aleatoria**
tamano_muestra = 50
muestra_principal = np.random.choice(df['PESO'],
                                     tamano_muestra) # choice nos permmite sacar unos datos

sns.histplot(muestra_principal, kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)

plt.show()

# %%
# @title **B. Histograma vs Densidad Normal - Todas las variables**
plt.figure(figsize=(8, 4))

tamano_muestra = 50

# Boxplot de las ASISTENCIA2
plt.subplot(2, 3, 1)
muestra_principal1 = np.random.choice(df['ASISTENCIA2'],
                                     tamano_muestra) # choice nos permmite sacar unos datos

sns.histplot(muestra_principal1, kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)

# plt.title('Distribución de Notas Definitivas')
plt.xlabel('ASISTENCIA2 - Valeria Castaño')


# Boxplot de las PARCIAL 1
plt.subplot(2, 3, 2)
muestra_principal2 = np.random.choice(df['PARCIAL 1'],
                                     tamano_muestra) # choice nos permmite sacar unos datos

sns.histplot(muestra_principal2, kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('PARCIAL 1 - Valeria Castaño')


# Boxplot de las PESO
plt.subplot(2, 3, 4)
muestra_principal3 = np.random.choice(df['PESO'],
                                     tamano_muestra) # choice nos permmite sacar unos datos

sns.histplot(muestra_principal3, kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('PESO - Valeria Castaño')

# Boxplot PESO
plt.subplot(2, 3, 5)
muestra_principal4 = np.random.choice(df['EDAD'],
                                     tamano_muestra) # choice nos permmite sacar unos datos

sns.histplot(muestra_principal4, kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('EDAD - Valeria Castaño')


# Histograma de la ASISTENCIA1
plt.subplot(2, 3, 3)

muestra_principal5 = np.random.choice(df['ESTATURA'],
                                     tamano_muestra) # choice nos permmite sacar unos datos

sns.histplot(muestra_principal5, kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('ESTATURA - Valeria Castaño')


# Boxplot de ASISTENCIA1
plt.subplot(2, 3, 6)
muestra_principal6 = np.random.choice(df['DEFINITIVA'],
                                     tamano_muestra) # choice nos permmite sacar unos datos

sns.histplot(muestra_principal6, kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),)
# plt.title('Distribución de Notas Definitivas')
plt.xlabel('DEFINITIVA - Valeria Castaño')

# ajustar espaciado entre subplot
plt.tight_layout()
plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T7"></a>
# ## **7. Tomando mil muestras -  para una variable**

# %%
# **A. Usando la tecnica de BootStrap seleccionaremos 1000 muestras aleatorias y las guardaremos**
muestras1 = np.array([]) #En este espacio guardaremos cada muestra tomada
num_muestras = 10000 # Este será el tamaño de las muestra
for m in range(num_muestras): # Con este procedimiento grantizamos tomar las mil muestras
    muestras1 = np.append(muestras1,
                         np.random.choice(df['ASISTENCIA2'],
                                          tamano_muestra,
                                          replace=True)) # guardamos en muestras las seleccionadas de la poblacion inicial
muestras1 = muestras1.reshape(-1, tamano_muestra)
muestras1.shape, muestras1 # nos muestras el tamaño del archivo y las muestras

# **d. Estamos realizando el muestreo de medias**
plt.hist(muestras1.mean(axis=1), bins=100, color="pink") # Histograma de la distribución muestral de la media
plt.xlabel("\nCalificaciones promedio de las muestras")
plt.ylabel("Frecuencia\n - Valeria Castaño")
plt.title("Distribución de las medias - Valeria Castaño")
plt.show()

# %%
# **B. Usando la tecnica de BootStrap seleccionaremos 1000 muestras aleatorias y las guardaremos**
sns.histplot(muestras1.mean(axis=1), kde=True, stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4), color='yellow')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T8"></a>
# ## **8. Tomando mil muestras -  Bootstraps para varias variables**

# %%
# @title **A. Usando la técnica de Bootstrap seleccionaremos 1000 muestras aleatorias y las guardaremos**
plt.figure(figsize=(12, 8))

# **A. Usando la técnica de Bootstrap seleccionaremos 1000 muestras aleatorias y las guardaremos**
# Inicializamos arrays para almacenar las medias de cada muestra
medias_asistencia = np.array([])
medias_parcial1 = np.array([])
medias_peso = np.array([])
medias_edad = np.array([])
medias_estatura = np.array([])
medias_definitiva = np.array([])

num_muestras = 1000  # Número de muestras bootstrap
tamano_muestra = len(df)  # Tamaño de cada muestra (mismo que el dataset original)

for _ in range(num_muestras):
    # Muestra bootstrap para cada variable y calculamos su media
    muestra_asistencia = np.random.choice(df['ASISTENCIA2'], tamano_muestra, replace=True)
    medias_asistencia = np.append(medias_asistencia, np.mean(muestra_asistencia))

    muestra_parcial1 = np.random.choice(df['PARCIAL 1'], tamano_muestra, replace=True)
    medias_parcial1 = np.append(medias_parcial1, np.mean(muestra_parcial1))

    muestra_peso = np.random.choice(df['PESO'], tamano_muestra, replace=True)
    medias_peso = np.append(medias_peso, np.mean(muestra_peso))

    muestra_edad = np.random.choice(df['EDAD'], tamano_muestra, replace=True)
    medias_edad = np.append(medias_edad, np.mean(muestra_edad))

    muestra_estatura = np.random.choice(df['ESTATURA'], tamano_muestra, replace=True)
    medias_estatura = np.append(medias_estatura, np.mean(muestra_estatura))

    muestra_definitiva = np.random.choice(df['DEFINITIVA'], tamano_muestra, replace=True)
    medias_definitiva = np.append(medias_definitiva, np.mean(muestra_definitiva))

# Visualización de las distribuciones de las medias
# Histograma de ASISTENCIA2
plt.subplot(2, 3, 1)
sns.histplot(medias_asistencia, kde=True, stat="density",
             alpha=.4, edgecolor=(1, 1, 1, .4), color='pink')
plt.xlabel('Media de ASISTENCIA2')
plt.ylabel('Densidad')

# Histograma de PARCIAL 1
plt.subplot(2, 3, 2)
sns.histplot(medias_parcial1, kde=True, stat="density",
             alpha=.4, edgecolor=(1, 1, 1, .4), color='yellow')
plt.xlabel('Media de PARCIAL 1')
plt.ylabel('Densidad')

# Histograma de PESO
plt.subplot(2, 3, 3)
sns.histplot(medias_peso, kde=True, stat="density",
             alpha=.4, edgecolor=(1, 1, 1, .4), color='lightblue')
plt.xlabel('Media de PESO')
plt.ylabel('Densidad')

# Histograma de EDAD
plt.subplot(2, 3, 4)
sns.histplot(medias_edad, kde=True, stat="density",
             alpha=.4, edgecolor=(1, 1, 1, .4), color='teal')
plt.xlabel('Media de EDAD')
plt.ylabel('Densidad')

# Histograma de ESTATURA
plt.subplot(2, 3, 5)
sns.histplot(medias_estatura, kde=True, stat="density",
             alpha=.4, edgecolor=(1, 1, 1, .4), color='violet')
plt.xlabel('Media de ESTATURA')
plt.ylabel('Densidad')

# Histograma de DEFINITIVA
plt.subplot(2, 3, 6)
sns.histplot(medias_definitiva, kde=True, stat="density",
             alpha=.4, edgecolor=(1, 1, 1, .4), color='salmon')
plt.xlabel('Media de DEFINITIVA')
plt.ylabel('Densidad')

# Ajustar espaciado entre subplots
plt.tight_layout()
plt.suptitle('Distribución de las medias mediante Bootstrap - Valeria Castaño', y=1.02)
plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T9"></a>
# ## **9. Regresión Lineal Simple**

# %%
# @title **A. Nuestras librerias mas usadas**
import numpy as np
from numpy.linalg import inv
import pandas as pd # para manejar los datos
import matplotlib.pyplot as plt # Para visualizar los datos
import random
import seaborn as sns
from sklearn.metrics import r2_score

# %%
# @title **B.  Vamos hallar la Matriz de Correlaciones de nuestra data**
# Seleccionar solo las columnas numéricas para calcular la correlación
df3 = df.select_dtypes(include=np.number)
df3
# Out:
#     ASISTENCIA2  ASISTENCIA1  PARCIAL 1  PARCIAL 2   NRC  EDAD  PESO  \
# 0           100           90        3.6       4.30  2314    20    55
# 1            70           75        0.9       2.50  1136    18    80
# 2            85           95        3.9       3.80  2314    19    60
# 3             5            5        2.9       0.50  2314    18    72
# 4            20           70        3.7       0.55  1009    19    45
# ..          ...          ...        ...        ...   ...   ...   ...
# 69           90           90        2.3       2.10  2314    18    59
# 70           85           95        2.0       3.10  2314    18    60
# 71           65           75        1.7       2.95  1136    20    55
# 72          100          100        2.3       3.20  2313    19    67
# 73          100          100        3.8       3.10  1136    18    60
#
#     ESTATURA  DEFINITIVA
# 0        160         3.6
# 1        185         0.9
# 2        158         3.9
# 3        181         2.9
# 4        163         3.7
# ..       ...         ...
# 69       176         2.3
# 70       171         2.0
# 71       164         1.7
# 72       171         2.3
# 73       165         3.8
#
# [74 rows x 9 columns]

# %%
# @title **C.  Vamos eliminar la columna "NRC"**

df3 = df3.drop(columns=['NRC'])
df3
# Out:
#     ASISTENCIA2  ASISTENCIA1  PARCIAL 1  PARCIAL 2  EDAD  PESO  ESTATURA  \
# 0           100           90        3.6       4.30    20    55       160
# 1            70           75        0.9       2.50    18    80       185
# 2            85           95        3.9       3.80    19    60       158
# 3             5            5        2.9       0.50    18    72       181
# 4            20           70        3.7       0.55    19    45       163
# ..          ...          ...        ...        ...   ...   ...       ...
# 69           90           90        2.3       2.10    18    59       176
# 70           85           95        2.0       3.10    18    60       171
# 71           65           75        1.7       2.95    20    55       164
# 72          100          100        2.3       3.20    19    67       171
# 73          100          100        3.8       3.10    18    60       165
#
#     DEFINITIVA
# 0          3.6
# 1          0.9
# 2          3.9
# 3          2.9
# 4          3.7
# ..         ...
# 69         2.3
# 70         2.0
# 71         1.7
# 72         2.3
# 73         3.8
#
# [74 rows x 8 columns]

# %%
# @title **D.  Calcular la matriz de correlación en el DataFrame numérico**
df3.corr().round(2)
# Out:
#              ASISTENCIA2  ASISTENCIA1  PARCIAL 1  PARCIAL 2  EDAD  PESO  \
# ASISTENCIA2         1.00         0.63       0.08       0.73  0.04 -0.06
# ASISTENCIA1         0.63         1.00       0.10       0.49  0.05 -0.04
# PARCIAL 1           0.08         0.10       1.00       0.35 -0.20  0.01
# PARCIAL 2           0.73         0.49       0.35       1.00 -0.11 -0.03
# EDAD                0.04         0.05      -0.20      -0.11  1.00  0.06
# PESO               -0.06        -0.04       0.01      -0.03  0.06  1.00
# ESTATURA           -0.04        -0.13      -0.11      -0.07 -0.08  0.66
# DEFINITIVA          0.08         0.10       1.00       0.35 -0.20  0.01
#
#              ESTATURA  DEFINITIVA
# ASISTENCIA2     -0.04        0.08
# ASISTENCIA1     -0.13        0.10
# PARCIAL 1       -0.11        1.00
# PARCIAL 2       -0.07        0.35
# EDAD            -0.08       -0.20
# PESO             0.66        0.01
# ESTATURA         1.00       -0.11
# DEFINITIVA      -0.11        1.00

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T10"></a>
# ## **10. Matriz de correlación**

# %%
# @title **A.  Calcular la matriz de correlación en el DataFrame numérico**
df3.corr().round(2)
# Out:
#              ASISTENCIA2  ASISTENCIA1  PARCIAL 1  PARCIAL 2  EDAD  PESO  \
# ASISTENCIA2         1.00         0.63       0.08       0.73  0.04 -0.06
# ASISTENCIA1         0.63         1.00       0.10       0.49  0.05 -0.04
# PARCIAL 1           0.08         0.10       1.00       0.35 -0.20  0.01
# PARCIAL 2           0.73         0.49       0.35       1.00 -0.11 -0.03
# EDAD                0.04         0.05      -0.20      -0.11  1.00  0.06
# PESO               -0.06        -0.04       0.01      -0.03  0.06  1.00
# ESTATURA           -0.04        -0.13      -0.11      -0.07 -0.08  0.66
# DEFINITIVA          0.08         0.10       1.00       0.35 -0.20  0.01
#
#              ESTATURA  DEFINITIVA
# ASISTENCIA2     -0.04        0.08
# ASISTENCIA1     -0.13        0.10
# PARCIAL 1       -0.11        1.00
# PARCIAL 2       -0.07        0.35
# EDAD            -0.08       -0.20
# PESO             0.66        0.01
# ESTATURA         1.00       -0.11
# DEFINITIVA      -0.11        1.00

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T11"></a>
# ## **11. Regresión lineal - MINIMOS CUADRADOS - Least Squares**

# %%
# @title **A.  Regresión lineal - MINIMOS CUADRADOS - Least Squares**
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# @title **B.  Regresión lineal - MINIMOS CUADRADOS - OLS**
# nuestras variables independiente y dependiente

X = df3['ESTATURA']
y = df3['PESO']

# para obtener intercepción -- esto es opcional

X = sm.add_constant(X)

# ajustar el modelo de regresión

reg = sm.OLS(y, X).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   PESO   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.425
# Method:                 Least Squares   F-statistic:                     54.99
# Date:                Thu, 09 Oct 2025   Prob (F-statistic):           1.88e-10
# Time:                        16:55:18   Log-Likelihood:                -263.30
# No. Observations:                  74   AIC:                             530.6
# Df Residuals:                      72   BIC:                             535.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -84.1267     19.909     -4.226      0.000    -123.815     -44.439
# ESTATURA       0.8756      0.118      7.416      0.000       0.640       1.111
# ==============================================================================
# Omnibus:                        5.164   Durbin-Watson:                   2.163
# Prob(Omnibus):                  0.076   Jarque-Bera (JB):                5.494
# Skew:                           0.308   Prob(JB):                       0.0641
# Kurtosis:                       4.184   Cond. No.                     3.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# @title Diagrama de Regresión y Recta (OLS)

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Define independent and dependent variables (using the already defined df3 and reg from cell qANbJ17MKNNu)
datax = df3['ESTATURA']
datay = df3['PESO']

# Get the OLS regression parameters from the previously calculated 'reg' object
p0_ols = reg.params['const']
p1_ols = reg.params['ESTATURA']
r_squared = reg.rsquared # Get the R-squared value

# Define the function for the OLS line
def ols_line(x, p0, p1):
    return p0 + p1 * x

# Plot the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(datax, datay, label="Datos", alpha=0.6, color='pink')

# Plot the OLS regression line
x_plot = np.linspace(datax.min(), datax.max(), 100)
plt.plot(x_plot, ols_line(x_plot, p0_ols, p1_ols), color="lightblue", label="Recta de Regresión (OLS)")

# Add the regression equation and R-squared value to the plot
equation_text = f'y = {p1_ols:.2f}x + {p0_ols:.2f}'
r_squared_text = f'$R^2$ = {r_squared:.2f}'

plt.text(0.05, 0.95, equation_text, transform=plt.gca().transAxes, fontsize=12,
         verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='wheat', alpha=0.5))
plt.text(0.05, 0.88, r_squared_text, transform=plt.gca().transAxes, fontsize=12,
         verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='wheat', alpha=0.5))

plt.xlabel("ESTATURA")
plt.ylabel("PESO")
plt.title("Diagrama de Regresión Lineal (OLS): PESO vs ESTATURA - Valeria Castaño")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)
