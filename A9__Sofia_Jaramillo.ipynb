# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/CURSO5/blob/main/A9__Sofia_Jaramillo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ᴄᴜʀꜱᴏ ᴅᴇ ᴇꜱᴛᴀᴅɪꜱᴛɪᴄᴀ ʏ ᴘʀᴏʙᴀʙɪʟɪᴅᴀᴅ - ᴜᴛʙ**
# # **𝐋𝐚𝐛𝐨𝐫𝐚𝐭𝐨𝐫𝐢𝐨 𝟏𝟎**
# ***Sofia Jaramillo Morales***

# %%
# Importar pandas
import pandas as pd

# Lista de edades
edades = [
    19,18,18,21,18,18,18,17,18,22,18,18,18,18,18,22,21,19,18,19,18,19,18,17,
    19,20,19,18,17,18,20,19,20,22,18,19,19,18,19,20,19,18,17,19,19,19,19,18,
    17,18,19,20,23,18,18,20,18,18,18,18,18,19,17,17,20,19,18,19,19,21,19,21,
    17,19,18,18,17,17,18,18,17,18,19,17,18,18,18,18,20,18,18,18,17,19,18,17,
    18,18,18,18,18,18,18,18,19,18,19,18,18,17,18,18,18,18,18,18,18,18,24,18,
    19,19,18,17,17,17,20,17,18,17,18,18,19,18,18,18
]

# Crear un DataFrame
df = pd.DataFrame(edades, columns=["Edad"])

# Mostrar los datos
df
# Out:
#      Edad
# 0      19
# 1      18
# 2      18
# 3      21
# 4      18
# ..    ...
# 131    18
# 132    19
# 133    18
# 134    18
# 135    18
#
# [136 rows x 1 columns]

# %% [markdown]
# # **𝟏. 𝐇𝐚𝐥𝐥𝐞 𝐦𝐞𝐝𝐢𝐝𝐚𝐬 𝐝𝐞 𝐭𝐞𝐧𝐝𝐞𝐧𝐜𝐢𝐚 𝐜𝐞𝐧𝐭𝐫𝐚𝐥 𝐩𝐚𝐫𝐚 𝐝𝐚𝐭𝐨𝐬 𝐢𝐧𝐝𝐢𝐯𝐢𝐝𝐮𝐚𝐥𝐞𝐬: 𝐌𝐞𝐝𝐢𝐚, 𝐌𝐞𝐝𝐢𝐚𝐧𝐚 𝐲 𝐌𝐨𝐝𝐚**
#
# ---

# %%
# Importar librerías
import pandas as pd

# Lista de edades
edades = [
    19,18,18,21,18,18,18,17,18,22,18,18,18,18,18,22,21,19,18,19,18,19,18,17,
    19,20,19,18,17,18,20,19,20,22,18,19,19,18,19,20,19,18,17,19,19,19,19,18,
    17,18,19,20,23,18,18,20,18,18,18,18,18,19,17,17,20,19,18,19,19,21,19,21,
    17,19,18,18,17,17,18,18,17,18,19,17,18,18,18,18,20,18,18,18,17,19,18,17,
    18,18,18,18,18,18,18,18,19,18,19,18,18,17,18,18,18,18,18,18,18,18,24,18,
    19,19,18,17,17,17,20,17,18,17,18,18,19,18,18,18
]

# Crear DataFrame
df = pd.DataFrame(edades, columns=["Edad"])

# Calcular medidas de tendencia central
media = df["Edad"].mean()
mediana = df["Edad"].median()
moda = df["Edad"].mode()[0]

# Mostrar resultados
print("1. Medidas de tendencia central para datos individuales:")
print(f"Media: {media:.2f}")
print(f"Mediana: {mediana}")
print(f"Moda: {moda}")
# Out:
# 1. Medidas de tendencia central para datos individuales:
# Media: 18.46
# Mediana: 18.0
# Moda: 18

# %% [markdown]
# # **𝟐.  𝐇𝐚𝐥𝐥𝐞 𝐦𝐞𝐝𝐢𝐝𝐚𝐬 𝐝𝐞 𝐩𝐨𝐬𝐢𝐜𝐢ó𝐧 𝐩𝐚𝐫𝐚 𝐝𝐚𝐭𝐨𝐬 𝐢𝐧𝐝𝐢𝐯𝐢𝐝𝐮𝐚𝐥𝐞𝐬: 𝐐𝟏, 𝐐𝟑, 𝐃𝟑, 𝐃𝟖 𝐞 𝐢𝐧𝐭𝐞𝐫𝐩𝐫𝐞𝐭𝐞 𝐥𝐨𝐬 𝐯𝐚𝐥𝐨𝐫𝐞𝐬 𝐞𝐧𝐜𝐨𝐧𝐭𝐫𝐚𝐝𝐨𝐬**

# %%
# Calcular medidas de posición
q1 = df["Edad"].quantile(0.25)  # Primer cuartil
q3 = df["Edad"].quantile(0.75)  # Tercer cuartil
d3 = df["Edad"].quantile(0.3)   # Tercer decil
d8 = df["Edad"].quantile(0.8)   # Octavo decil

# Imprimir resultados e interpretación
print("2. Medidas de posición para datos individuales:\n")

print(f"Q1 (Primer Cuartil)  = {q1}")
print(f"Q3 (Tercer Cuartil)  = {q3}")
print(f"D3 (Tercer Decil)    = {d3}")
print(f"D8 (Octavo Decil)    = {d8}")
# Out:
# 2. Medidas de posición para datos individuales:
#
# Q1 (Primer Cuartil)  = 18.0
# Q3 (Tercer Cuartil)  = 19.0
# D3 (Tercer Decil)    = 18.0
# D8 (Octavo Decil)    = 19.0

# %%
# Mostrar interpretaciones de medidas de posición

print("-Interpretación de medidas de posición:\n")

print("Q1 (Primer cuartil = 18):")
print("El 25% de los estudiantes tienen 18 años o menos. Esto indica que una cuarta parte del grupo está conformado por los más jóvenes del conjunto.\n")

print("Q3 (Tercer cuartil = 19):")
print("El 75% de los estudiantes tienen 19 años o menos. Es decir, solo el 25% restante tiene más de 19 años.\n")

print("D3 (Tercer decil = 18):")
print("El 30% de los estudiantes tienen 18 años o menos, lo cual reafirma que la mayoría se concentra en ese rango bajo de edad.\n")

print("D8 (Octavo decil = 19):")
print("El 80% de los estudiantes tienen 20 años o menos, lo que muestra que solo una pequeña parte (el 20%) supera esa edad.")
# Out:
# -Interpretación de medidas de posición:
#
# Q1 (Primer cuartil = 18):
# El 25% de los estudiantes tienen 18 años o menos. Esto indica que una cuarta parte del grupo está conformado por los más jóvenes del conjunto.
#
# Q3 (Tercer cuartil = 19):
# El 75% de los estudiantes tienen 19 años o menos. Es decir, solo el 25% restante tiene más de 19 años.
#
# D3 (Tercer decil = 18):
# El 30% de los estudiantes tienen 18 años o menos, lo cual reafirma que la mayoría se concentra en ese rango bajo de edad.
#
# D8 (Octavo decil = 19):
# El 80% de los estudiantes tienen 20 años o menos, lo que muestra que solo una pequeña parte (el 20%) supera esa edad.

# %% [markdown]
# # **𝟑. 𝐂𝐚𝐥𝐜𝐮𝐥𝐞 𝐞𝐥 𝐃𝐢𝐚𝐠𝐫𝐚𝐦𝐚 𝐝𝐞 𝐂𝐚𝐣𝐚 𝐝𝐞 𝐜𝐚𝐣𝐚 𝐲 𝐛𝐢𝐠𝐨𝐭𝐞𝐬 𝐞 𝐢𝐧𝐭𝐞𝐫𝐩𝐫𝐞𝐭𝐞 𝐥𝐨𝐬 𝐯𝐚𝐥𝐨𝐫𝐞𝐬 𝐚𝐭í𝐩𝐢𝐜𝐨𝐬 𝐬𝐢 𝐥𝐨𝐬 𝐡𝐚𝐲**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Calcular Q1, Q3 e IQR
q1 = np.percentile(edades, 25)
q3 = np.percentile(edades, 75)
iqr = q3 - q1

# Límites para detectar atípicos
limite_inferior = q1 - 1.5 * iqr
limite_superior = q3 + 1.5 * iqr

# Detectar valores atípicos
valores_atipicos = [x for x in edades if x < limite_inferior or x > limite_superior]

# Mostrar el diagrama de caja
plt.figure(figsize=(10, 2))
sns.boxplot(x=edades, color='lightblue')
plt.title(" Diagrama de Caja y Bigotes - Edades / Sofia Jaramillo")
plt.xlabel("Edad")
plt.grid(axis='x')
plt.show()

# Imprimir resultados
print(" Valores atípicos detectados:")
if valores_atipicos:
    print(sorted(set(valores_atipicos)))
else:
    print("No se detectaron valores atípicos.")
# Out:
#  Valores atípicos detectados:
# [21, 22, 23, 24]

# %% [markdown]
# **Los valores 21, 22, 23 y 24 años se encuentran fuera del rango normal de edades del grupo.**
#
# Estos datos se consideran atípicos porque superan el límite superior del rango intercuartílicO, lo que indica que están significativamente por encima de la mayoría de las edades (que se concentran entre los 17 y 20 años).

# %% [markdown]
# # **𝟒. 𝐂𝐨𝐧𝐬𝐭𝐫𝐮𝐲𝐚 𝐥𝐚 𝐓𝐚𝐛𝐥𝐚 𝐚𝐠𝐫𝐮𝐩𝐚𝐝𝐚 𝐝𝐞 𝐟𝐫𝐞𝐜𝐮𝐞𝐧𝐜𝐢𝐚𝐬 𝐭𝐚𝐥 𝐜𝐨𝐦𝐨 𝐬𝐞 𝐢𝐧𝐝𝐢𝐜𝐚 𝐞𝐧 𝐞𝐥 𝐕𝐈𝐃𝐄𝐎 𝟏**

# %%
import pandas as pd
import numpy as np
import math

# Usamos los valores de edad ya proporcionados anteriormente
df = pd.DataFrame(edades, columns=["Edad"])

# Paso 1: Número de clases (Regla de Sturges)
n = len(df)
k = round(1 + 3.322 * math.log10(n))

# Paso 2: Rango y amplitud
rango = df["Edad"].max() - df["Edad"].min()
amplitud = math.ceil(rango / k)

# Paso 3: Crear intervalos
limite_inferior = df["Edad"].min()
bins = [limite_inferior + i * amplitud for i in range(k + 1)]

# Paso 4: Cortar datos en intervalos
intervalos = pd.cut(df["Edad"], bins=bins, right=False)

# Paso 5: Calcular frecuencias
tabla = intervalos.value_counts().sort_index().reset_index()
tabla.columns = ["Intervalo", "Frecuencia"]

# Frecuencia acumulada
tabla["Frec. Acumulada"] = tabla["Frecuencia"].cumsum()

# Frecuencia relativa
tabla["Frec. Relativa"] = (tabla["Frecuencia"] / n).round(2)

# Frecuencia relativa acumulada
tabla["Frec. Rel. Acum."] = tabla["Frec. Relativa"].cumsum().round(2)

# Mostrar tabla
print("Tabla de Frecuencias Agrupadas:")
print(tabla.to_string(index=False))
# Out:
# Tabla de Frecuencias Agrupadas:
# Intervalo  Frecuencia  Frec. Acumulada  Frec. Relativa  Frec. Rel. Acum.
#  [17, 18)          20               20            0.15              0.15
#  [18, 19)          69               89            0.51              0.66
#  [19, 20)          29              118            0.21              0.87
#  [20, 21)           9              127            0.07              0.94
#  [21, 22)           4              131            0.03              0.97
#  [22, 23)           3              134            0.02              0.99
#  [23, 24)           1              135            0.01              1.00
#  [24, 25)           1              136            0.01              1.01

# %% [markdown]
# # **𝟓. 𝐂𝐨𝐧𝐬𝐭𝐫𝐮𝐲𝐚 𝐞𝐥 𝐇𝐢𝐬𝐭𝐨𝐠𝐫𝐚𝐦𝐚 𝐝𝐞 𝐟𝐫𝐞𝐜𝐮𝐞𝐧𝐜𝐢𝐚𝐬 𝐚𝐛𝐬𝐨𝐥𝐮𝐭𝐚𝐬 𝐲 𝐝𝐢𝐛𝐮𝐣𝐞 𝐞𝐥 𝐩𝐨𝐥í𝐠𝐨𝐧𝐨**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# Usamos los datos de edades proporcionados anteriormente
df = pd.DataFrame(edades, columns=["Edad"])

# Número de clases (Sturges)
n = len(df)
k = round(1 + 3.322 * math.log10(n))

# Rango y amplitud
rango = df["Edad"].max() - df["Edad"].min()
amplitud = math.ceil(rango / k)

# Bins
limite_inferior = df["Edad"].min()
bins = [limite_inferior + i * amplitud for i in range(k + 1)]

# Intervalos y tabla
frecuencias = pd.cut(df["Edad"], bins=bins, right=False)
tabla = frecuencias.value_counts().sort_index().reset_index()
tabla.columns = ["Intervalo", "Frecuencia"]
tabla["Marca de clase"] = [(interval.left + interval.right) / 2 for interval in tabla["Intervalo"]]

# Gráfico
plt.figure(figsize=(10, 6))

# Histograma: color lavanda
plt.bar(tabla["Marca de clase"], tabla["Frecuencia"],
        width=amplitud, align='center', alpha=0.8, edgecolor='black',
        color='#cdb4db', label="Histograma")

# Polígono: azul oscuro con puntos azul cielo
plt.plot(tabla["Marca de clase"], tabla["Frecuencia"],
         marker='o', color='#3a0ca3', linewidth=2, label="Polígono")
plt.scatter(tabla["Marca de clase"], tabla["Frecuencia"], color='#4cc9f0', zorder=5)

# Estética del gráfico
plt.title("Histograma y Polígono de Frecuencias - Sofia Jaramillo", fontsize=14)
plt.xlabel("Edad", fontsize=12)
plt.ylabel("Frecuencia", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **𝟔. 𝐂𝐨𝐧𝐬𝐭𝐫𝐮𝐲𝐚 𝐞𝐥 𝐇𝐢𝐬𝐭𝐨𝐠𝐫𝐚𝐦𝐚 𝐝𝐞 𝐟𝐫𝐞𝐜𝐮𝐞𝐧𝐜𝐢𝐚𝐬 𝐫𝐞𝐥𝐚𝐭𝐢𝐯𝐚𝐬 𝐲 𝐩𝐨𝐥í𝐠𝐨𝐧𝐨**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# Usamos los datos de edades ya proporcionados
df = pd.DataFrame(edades, columns=["Edad"])

# Número de clases (Sturges)
n = len(df)
k = round(1 + 3.322 * math.log10(n))

# Rango y amplitud
rango = df["Edad"].max() - df["Edad"].min()
amplitud = math.ceil(rango / k)

# Bins
limite_inferior = df["Edad"].min()
bins = [limite_inferior + i * amplitud for i in range(k + 1)]

# Intervalos
frecuencias = pd.cut(df["Edad"], bins=bins, right=False)
tabla = frecuencias.value_counts().sort_index().reset_index()
tabla.columns = ["Intervalo", "Frecuencia"]

# Marca de clase y frecuencia relativa
tabla["Marca de clase"] = [(interval.left + interval.right) / 2 for interval in tabla["Intervalo"]]
tabla["Frecuencia Relativa"] = tabla["Frecuencia"] / n

# Gráfico
plt.figure(figsize=(10, 6))

# Histograma: verde salvia suave
plt.bar(tabla["Marca de clase"], tabla["Frecuencia Relativa"],
        width=amplitud, align='center', alpha=0.95,
        edgecolor='#6B4226', color='#B5CDA3', label="Histograma Relativo")

# Polígono: rosa viejo con puntos pastel
plt.plot(tabla["Marca de clase"], tabla["Frecuencia Relativa"],
         marker='o', color='#A26769', linewidth=2.5, label="Polígono Relativo")
plt.scatter(tabla["Marca de clase"], tabla["Frecuencia Relativa"], color='#E4BAD4', s=80, zorder=5)

# Estética
plt.title("Histograma y Polígono de Frecuencias Relativas", fontsize=15, color="#4B3F3F")
plt.xlabel("Edad", fontsize=12)
plt.ylabel("Frecuencia Relativa", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **𝟕. 𝐂𝐨𝐧𝐬𝐭𝐫𝐮𝐲𝐚 𝐞𝐥 𝐇𝐢𝐬𝐭𝐨𝐠𝐫𝐚𝐦𝐚 𝐝𝐞 𝐟𝐫𝐞𝐜𝐮𝐞𝐧𝐜𝐢𝐚𝐬 𝐚𝐜𝐮𝐦𝐮𝐥𝐚𝐝𝐚𝐬 𝐲 𝐩𝐨𝐥í𝐠𝐨𝐧𝐨**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Crear tabla de frecuencias acumuladas
df = pd.DataFrame(edades, columns=['Edad'])
frecuencia = df['Edad'].value_counts().sort_index()
frecuencia_acumulada = frecuencia.cumsum()

# Datos para graficar
edades_ordenadas = frecuencia_acumulada.index
valores_acumulados = frecuencia_acumulada.values

# Paleta de colores
color_barras = '#A8D5BA'   # Verde menta suave
color_linea = '#89BFE2'    # Azul cielo
color_puntos = '#F3B0C3'   # Rosado pastel

# Crear el gráfico
plt.figure(figsize=(10, 5))
plt.bar(edades_ordenadas, valores_acumulados, width=0.8, color=color_barras, label='Histograma Acumulado')

# Polígono de frecuencias acumuladas
plt.plot(edades_ordenadas, valores_acumulados, marker='o', color=color_linea, linewidth=2.5, label='Polígono Acumulado')
plt.scatter(edades_ordenadas, valores_acumulados, color=color_puntos, zorder=5)

# Estética del gráfico
plt.title("Histograma y Polígono de Frecuencias Acumuladas - Sofia Jaramillo", fontsize=14)
plt.xlabel("Edad")
plt.ylabel("Frecuencia Acumulada")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.legend()
plt.xticks(edades_ordenadas)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **𝟖. 𝐌𝐞𝐝𝐢𝐝𝐚𝐬 𝐝𝐞 𝐭𝐞𝐧𝐝𝐞𝐧𝐜𝐢𝐚 𝐜𝐞𝐧𝐭𝐫𝐚𝐥 𝐚𝐠𝐫𝐮𝐩𝐚𝐝𝐚𝐬: 𝐌𝐞𝐝𝐢𝐚, 𝐌𝐞𝐝𝐢𝐚𝐧𝐚 𝐲 𝐌𝐨𝐝𝐚**

# %%
import pandas as pd
import numpy as np
import math

# Usamos la lista de edades proporcionada anteriormente
df = pd.DataFrame(edades, columns=["Edad"])

# Paso 1: Calcular número de clases (Sturges)
n = len(df)
k = round(1 + 3.322 * math.log10(n))

# Paso 2: Calcular el rango y la amplitud
rango = df["Edad"].max() - df["Edad"].min()
amplitud = math.ceil(rango / k)

# Paso 3: Crear los intervalos
limite_inferior = df["Edad"].min()
bins = [limite_inferior + i * amplitud for i in range(k + 1)]
frecuencias = pd.cut(df["Edad"], bins=bins, right=False)
tabla = frecuencias.value_counts().sort_index().reset_index()
tabla.columns = ["Intervalo", "Frecuencia"]

# Paso 4: Agregar marca de clase
tabla["Marca de clase"] = [(interval.left + interval.right) / 2 for interval in tabla["Intervalo"]]
tabla["FA"] = tabla["Frecuencia"].cumsum()

# Media agrupada
media = np.average(tabla["Marca de clase"], weights=tabla["Frecuencia"])

# Mediana agrupada
N = n
N_2 = N / 2
tabla["Frec. Acum. Ant."] = tabla["FA"] - tabla["Frecuencia"]

for i, row in tabla.iterrows():
    if row["FA"] >= N_2:
        LI = row["Intervalo"].left
        Fi = row["Frecuencia"]
        F_ant = row["Frec. Acum. Ant."]
        mediana = LI + ((N_2 - F_ant) / Fi) * amplitud
        break

# Moda agrupada
moda_idx = tabla["Frecuencia"].idxmax()
LI_moda = tabla.loc[moda_idx, "Intervalo"].left
f1 = tabla.loc[moda_idx, "Frecuencia"]
f0 = tabla.loc[moda_idx - 1, "Frecuencia"] if moda_idx > 0 else 0
f2 = tabla.loc[moda_idx + 1, "Frecuencia"] if moda_idx + 1 < len(tabla) else 0

moda = LI_moda + ((f1 - f0) / ((2 * f1) - f0 - f2)) * amplitud

# Mostrar resultados
print(f"Media agrupada: {media:.2f}")
print(f"Mediana agrupada: {mediana:.2f}")
print(f"Moda agrupada: {moda:.2f}")
# Out:
# Media agrupada: 18.96
# Mediana agrupada: 18.70
# Moda agrupada: 18.55

# %% [markdown]
# # **𝟗. 𝐇𝐚𝐥𝐥𝐞 𝐦𝐞𝐝𝐢𝐝𝐚𝐬 𝐝𝐞 𝐩𝐨𝐬𝐢𝐜𝐢ó𝐧 𝐩𝐚𝐫𝐚 𝐝𝐚𝐭𝐨𝐬 𝐚𝐠𝐫𝐮𝐩𝐚𝐝𝐨𝐬: 𝐐𝟏, 𝐐𝟑, 𝐃𝟑, 𝐃𝟖 𝐞 𝐢𝐧𝐭𝐞𝐫𝐩𝐫𝐞𝐭𝐞 𝐥𝐨𝐬 𝐯𝐚𝐥𝐨𝐫𝐞𝐬 𝐞𝐧𝐜𝐨𝐧𝐭𝐫𝐚𝐝𝐨𝐬**

# %%
import pandas as pd
import numpy as np
import math

# Usaremos la lista de edades ya indicada previamente
df = pd.DataFrame(edades, columns=["Edad"])

# Total de datos
n = len(df)

# Número de clases con regla de Sturges
k = round(1 + 3.322 * math.log10(n))

# Rango y amplitud
rango = df["Edad"].max() - df["Edad"].min()
amplitud = math.ceil(rango / k)

# Crear los intervalos (bins)
limite_inferior = df["Edad"].min()
bins = [limite_inferior + i * amplitud for i in range(k + 1)]

# Tabla de frecuencias
frecuencias = pd.cut(df["Edad"], bins=bins, right=False)
tabla = frecuencias.value_counts().sort_index().reset_index()
tabla.columns = ["Intervalo", "Frecuencia"]
tabla["Marca de clase"] = [(interval.left + interval.right) / 2 for interval in tabla["Intervalo"]]
tabla["Frec. Acumulada"] = tabla["Frecuencia"].cumsum()

# Función para calcular medidas de posición agrupadas
def medida_posicion(porcentaje):
    pos = (porcentaje / 100) * n
    for i in range(len(tabla)):
        if tabla.loc[i, "Frec. Acumulada"] >= pos:
            Li = tabla.loc[i, "Intervalo"].left
            Fi = tabla.loc[i, "Frecuencia"]
            Fa = tabla.loc[i - 1, "Frec. Acumulada"] if i > 0 else 0
            return round(Li + ((pos - Fa) / Fi) * amplitud, 2)

# Calcular Q1, Q3, D3, D8
Q1 = medida_posicion(25)
Q3 = medida_posicion(75)
D3 = medida_posicion(30)
D8 = medida_posicion(80)

# Mostrar resultados
print("Medidas de posición para datos agrupados:")
print(f"Q1 (25%): {Q1}")
print(f"Q3 (75%): {Q3}")
print(f"D3 (30%): {D3}")
print(f"D8 (80%): {D8}")
# Out:
# Medidas de posición para datos agrupados:
# Q1 (25%): 18.2
# Q3 (75%): 19.45
# D3 (30%): 18.3
# D8 (80%): 19.68

# %% [markdown]
# **a) Q1 (Primer Cuartil) = 18.2**
#
# El 25% de los estudiantes tienen menos de 18.2 años, lo que indica que una cuarta parte del grupo pertenece al segmento más joven de la población.
#
# **b) Q3 (Tercer Cuartil) = 19.45**
#
# El 75% de los estudiantes tienen menos de 19.45 años, y solo el 25% restante supera esa edad. Esto nos dice que la gran mayoría se encuentra por debajo de los 19.5 años.
#
# **c) D3 (Tercer Decil) = 18.3**
#
# El 30% de los estudiantes tienen menos de 18.3 años, reforzando que hay una concentración significativa en los primeros rangos de edad.
#
# **d) D8 (Octavo Decil) = 19.68**
#
# El 80% de los estudiantes tienen menos de 19.68 años, por lo que solo el 20% de la muestra supera ese punto. El grupo de mayor edad representa una pequeña fracción del total.

# %% [markdown]
# # **𝟏𝟎. 𝐂𝐨𝐧𝐬𝐭𝐫𝐮𝐲𝐚 𝐮𝐧 𝐢𝐧𝐭𝐞𝐫𝐯𝐚𝐥𝐨 𝐝𝐞 𝐂𝐨𝐧𝐟𝐢𝐚𝐧𝐳𝐚 𝐝𝐞 𝟗𝟓% 𝐩𝐚𝐫𝐚 𝐥𝐚 𝐦𝐞𝐝𝐢𝐚 𝐫𝐞𝐚𝐥 𝐝𝐞 𝐥𝐚 𝐧𝐨𝐭𝐚 𝐝𝐞𝐟𝐢𝐧𝐢𝐭𝐢𝐯𝐚 𝐞 𝐢𝐧𝐭𝐞𝐫𝐩𝐫𝐞𝐭𝐞 𝐞𝐥 𝐫𝐞𝐬𝐮𝐥𝐭𝐚𝐝𝐨.**

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm

# Simular 100 notas con distribución realista
np.random.seed(42)  # Fijar semilla para reproducibilidad
notas = np.random.normal(loc=3.8, scale=0.4, size=100)
notas = np.clip(notas, 2.5, 5.0)  # Limitar valores entre 2.5 y 5.0

# Crear DataFrame
df = pd.DataFrame(notas, columns=["Nota"])

# Calcular estadísticos
n = len(df)
media = df["Nota"].mean()
desviacion = df["Nota"].std(ddof=1)
z = norm.ppf(0.975)  # Valor z para 95% de confianza (1.96)

# Calcular intervalo de confianza
margen_error = z * (desviacion / np.sqrt(n))
IC_inf = media - margen_error
IC_sup = media + margen_error

# Resultados
print(f"Media muestral: {media:.2f}")
print(f"Intervalo de confianza del 95%: ({IC_inf:.2f}, {IC_sup:.2f})")
# Out:
# Media muestral: 3.76
# Intervalo de confianza del 95%: (3.69, 3.83)

# %% [markdown]
# Con un nivel de confianza del 95%, podemos afirmar que la media real de las notas definitivas de la población estudiantil se encuentra entre 3.74 y 3.90.
